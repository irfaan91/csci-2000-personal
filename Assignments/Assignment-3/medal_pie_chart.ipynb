# %%
#Irfaan Ali
#100400606

# %matplotlib inline
from pylab import *

#Initial size of pie chart
figure(1, figsize=(10,10))

#Names of each slice in pie chart
labels = 'USA', 'CHN', 'GBR', 'RUS', 'KOR' ,'GER', 'FRA', 'ITA', 'HUN', 'AUS', 'OTHER'

#Values of each slice of the pie
fracs = [46/302, 38/302, 29/302, 24/302, 13/302, 11/302, 
         11/302, 8/302, 8/302, 7/302, 107/302]

#Sets colour spectrum for the pie chart
cs=cm.Set1(np.arange(11)/11)

#Assigns values to the pyplot variables
pie(fracs, labels=labels, shadow=True, autopct='%1.1f%%',colors=cs)

#Title of the pie chart
title('2012 Olympic gold medals (100400606)')

matplotlib.pyplot.show()
