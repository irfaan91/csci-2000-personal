# %%
##Irfaan Ali
##100400606

# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import csv

#Aquiring Data from CSV file
np.cat = []
np.lat = []
np.long = []
np.cases = []
reader = open('Source_data_for_CFR_vaccine_map_abridged.csv', 'r')
data = csv.DictReader(reader)
for row in data:
    np.cat.append(row['Category'])
    np.lat.append((float)(row['Lat']))
    np.long.append((float)(row['Long']))
    np.cases.append((float)(row['Cases']))

# %%
#Earth Plot (code snippet from animation.ipynb)
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

##Plot for Measles
for i in range (len(np.cat)):
    if (np.cat[i] == 'Measles'):
        x, y = earth(np.long[i], np.lat[i])
        ##smaller cases that wouldn't show on map after scale
        if (np.cases[i] > 0 and np.cases[i] < 2000):
            earth.plot(x, y, 'ro',markersize=3,alpha=.5)    
        else: 
            ##max case 134042
            earth.plot(x, y, 'ro',markersize=((np.cases[i])/13500)*9,alpha=.5)

    
plt.title("Measles outbreaks (100400606)")
plt.show()

# %%
#Earth Plot (code snippet from animation.ipynb)
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

##Plot for Rubella
for i in range (len(np.cat)):
    if (np.cat[i] == 'Rubella'):
        x, y = earth(np.long[i], np.lat[i])
        if (np.cases[i] > 0 and np.cases[i] < 500):
            earth.plot(x, y, 'mo',markersize=4,alpha=.5)    
        else: 
            earth.plot(x, y, 'mo',markersize=((np.cases[i])/4000)*5,alpha=.5)

    
plt.title("Rubella outbreaks (100400606)")
plt.show()

# %%
#Earth Plot (code snippet from animation.ipynb)
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

##Plot for Mumps
for i in range (len(np.cat)):
    if (np.cat[i] == 'Mumps'):
        x, y = earth(np.long[i], np.lat[i])
        if (np.cases[i] > 0 and np.cases[i] < 500):
            earth.plot(x, y, 'go',markersize=5,alpha=.5)    
        else: 
            earth.plot(x, y, 'go',markersize=((np.cases[i])/5000)*10,alpha=.5)

    
plt.title("Mumps outbreaks (100400606)")
plt.show()

# %%
#Earth Plot (code snippet from animation.ipynb)
fig = plt.figure(figsize=(14,10))
ax = plt.subplot(1,1,1)
earth = Basemap(projection='mill')
earth.drawcoastlines(color='0.50', linewidth=0.25)
earth.fillcontinents(color='0.95')

##Plot for Polio
for i in range (len(np.cat)):
    if (np.cat[i] == 'Polio'):
        x, y = earth(np.long[i], np.lat[i])
        if (np.cases[i] > 0 and np.cases[i] < 100):
            earth.plot(x, y, 'bo',markersize=3,alpha=.5)    
        else: 
            earth.plot(x, y, 'bo',markersize=((np.cases[i])/500)*20,alpha=.5)

    
plt.title("Polio outbreaks (100400606)")
plt.show()
